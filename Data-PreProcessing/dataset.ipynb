# %%
import matplotlib.pyplot as plt
import numpy as np
from datasetClass import BengaliDatasetTrain
# %matplotlib inline

# %%
dataset = BengaliDatasetTrain(folds=[0,1],
                              img_height=137,
                              img_width=236,
                              mean=(0.485,0.456,0.406),
                              std=(0.229,0.224,0.225))
# mean & std values are from ResNet
len(dataset)
# Out:
# 80336

# %%
idx = 89 # change here to see output image
img = dataset[idx]["image"]
print(dataset[idx]["grapheme_root"])
print(dataset[idx]["vowel_diacritic"])
print(dataset[idx]["consonant_diacritic"])
npimg = img.numpy()
plt.imshow(np.transpose(npimg,(1,2,0)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tensor(109)
# tensor(3)
# tensor(0)
